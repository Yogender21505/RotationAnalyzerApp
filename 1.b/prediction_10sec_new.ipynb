# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Read the text file and preprocess the data
file_path = 'database.txt'
columns = ['roll', 'pitch', 'yaw', 'timestamp']
data = pd.read_csv(file_path, header=None, names=columns, sep=', ', engine='python')

# Convert timestamp to datetime format
data['timestamp'] = pd.to_datetime(data['timestamp'], format='%H:%M:%S:%f')

# Sort data by timestamp (if not already sorted)
data.sort_values(by='timestamp', inplace=True)
data.reset_index(drop=True, inplace=True)

# Extract orientation values (roll, pitch, yaw)
orientation_data = data[['roll', 'pitch', 'yaw']]

# Normalize the data using Min-Max scaling
scaler = MinMaxScaler(feature_range=(0, 1))
orientation_data_scaled = scaler.fit_transform(orientation_data)

# Function to prepare data for LSTM model
def prepare_data_for_lstm(data, window_size=10):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:(i + window_size)])
        y.append(data[i + window_size])
    return np.array(X), np.array(y)

# Set window size (number of time steps to look back)
window_size = 30  # Adjust based on your data and prediction horizon

# Prepare data for LSTM
X, y = prepare_data_for_lstm(orientation_data_scaled, window_size)

# Split data into training and testing sets
split_ratio = 0.8
split_index = int(split_ratio * len(X))

X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# Define LSTM model
model = Sequential()
model.add(LSTM(64, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(3))  # Output layer with 3 neurons (roll, pitch, yaw)

# Compile the model
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, verbose=1)

# Evaluate the model
loss = model.evaluate(X_test, y_test)
print(f'Test Loss: {loss}')

# Make predictions
predictions = model.predict(X_test)

# Inverse transform the predictions and actual values
predictions_inv = scaler.inverse_transform(predictions)
y_test_inv = scaler.inverse_transform(y_test)

# Plot actual vs predicted values
plt.figure(figsize=(12, 6))
plt.plot(y_test_inv[:, 0], label='Actual (roll)', color='blue')
plt.plot(predictions_inv[:, 0], label='Predicted (roll)', color='red')
plt.plot(y_test_inv[:, 1], label='Actual (pitch)', color='green')
plt.plot(predictions_inv[:, 1], label='Predicted (pitch)', color='orange')
plt.plot(y_test_inv[:, 2], label='Actual (yaw)', color='purple')
plt.plot(predictions_inv[:, 2], label='Predicted (yaw)', color='brown')
plt.xlabel('Time Steps')
plt.ylabel('Orientation Values')
plt.title('LSTM Model: Actual vs Predicted Orientation Values')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 15/15 [==============================] - 3s 49ms/step - loss: 0.0911 - val_loss: 0.0233
# Epoch 2/50
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0313 - val_loss: 0.0124
# Epoch 3/50
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0225 - val_loss: 0.0103
# Epoch 4/50
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0198 - val_loss: 0.0083
# Epoch 5/50
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0181 - val_loss: 0.0100
# Epoch 6/50
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0165 - val_loss: 0.0090
# Epoch 7/50
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0151 - val_loss: 0.0079
# Epoch 8/50
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0141 - val_loss: 0.0098
# Epoch 9/50
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0132 - val_loss: 0.0091
# Epoch 10/50
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0136 - val_loss: 0.0088
# Epoch 11/50
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0123 - val_loss: 0.0086
# Epoch 12/50
# 15/15 [==============================] - 0s 19ms/step - loss: 0.0120 - val_loss: 0.0091
# Epoch 13/50
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0117 - val_loss: 0.0092
# Epoch 14/50
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0116 - val_loss: 0.0089
# Epoch 15/50
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0113 - val_loss: 0.0084
# Epoch 16/50
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0110 - val_loss: 0.0096
# Epoch 17/50
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0110 - val_loss: 0.0096
# Epoch 18/50
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0129 - val_loss: 0.0076
# Epoch 19/50
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0115 - val_loss: 0.0079
# Epoch 20/50
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0108 - val_loss: 0.0074
# Epoch 21/50
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0106 - val_loss: 0.0093
# Epoch 22/50
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0105 - val_loss: 0.0077
# Epoch 23/50
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0101 - val_loss: 0.0089
# Epoch 24/50
# 15/15 [==============================] - 0s 23ms/step - loss: 0.0102 - val_loss: 0.0077
# Epoch 25/50
# 15/15 [==============================] - 0s 22ms/step - loss: 0.0100 - val_loss: 0.0078
# Epoch 26/50
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0098 - val_loss: 0.0089
# Epoch 27/50
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0101 - val_loss: 0.0076
# Epoch 28/50
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0100 - val_loss: 0.0076
# Epoch 29/50
# 15/15 [==============================] - 0s 14ms/step - loss: 0.0097 - val_loss: 0.0081
# Epoch 30/50
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0094 - val_loss: 0.0082
# Epoch 31/50
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0093 - val_loss: 0.0077
# Epoch 32/50
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0094 - val_loss: 0.0084
# Epoch 33/50
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0093 - val_loss: 0.0082
# Epoch 34/50
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0090 - val_loss: 0.0080
# Epoch 35/50
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0089 - val_loss: 0.0076
# Epoch 36/50
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0089 - val_loss: 0.0072
# Epoch 37/50
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0088 - val_loss: 0.0075
# Epoch 38/50
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0089 - val_loss: 0.0074
# Epoch 39/50
# 15/15 [==============================] - 0s 15ms/step - loss: 0.0087 - val_loss: 0.0085
# Epoch 40/50
# 15/15 [==============================] - 0s 17ms/step - loss: 0.0085 - val_loss: 0.0085
# Epoch 41/50
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0084 - val_loss: 0.0077
# Epoch 42/50
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0084 - val_loss: 0.0073
# Epoch 43/50
# 15/15 [==============================] - 1s 36ms/step - loss: 0.0084 - val_loss: 0.0079
# Epoch 44/50
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0089 - val_loss: 0.0077
# Epoch 45/50
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0089 - val_loss: 0.0078
# Epoch 46/50
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0110 - val_loss: 0.0074
# Epoch 47/50
# 15/15 [==============================] - 0s 33ms/step - loss: 0.0088 - val_loss: 0.0081
# Epoch 48/50
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0083 - val_loss: 0.0081
# Epoch 49/50
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0083 - val_loss: 0.0071
# Epoch 50/50
# 15/15 [==============================] - 1s 34ms/step - loss: 0.0081 - val_loss: 0.0069
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0064
# Test Loss: 0.006356322672218084
# 4/4 [==============================] - 0s 6ms/step

# %% [markdown]
# # New section
